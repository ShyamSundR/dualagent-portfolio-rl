# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from google.colab import drive
drive.mount('/content/drive')
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
def calc_risk_contribution(weights, cov_matrix):
    volatility = np.sqrt(weights.T @ cov_matrix @ weights)
    marginal_contribution = cov_matrix @ weights
    risk_contribution = np.multiply(weights, marginal_contribution)/volatility

    return risk_contribution

def risk_parity_objective(weights, cov_matrix):
    #Want risk contribution to be equal to each other
    risk_contribution = calc_risk_contribution(weights, cov_matrix)

    target = np.mean(risk_contribution)

    return np.sum((risk_contribution-target)**2)

def get_risk_parity_weights(cov_matrix):
    num_assets = len(cov_matrix)

    weights = np.ones(num_assets) / num_assets

    constraints = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1})
    bounds = [(0, 1) for i in range(num_assets)]

    result = minimize(risk_parity_objective, weights, args=(cov_matrix,),
                      method='SLSQP', bounds=bounds, constraints=constraints)

    return result.x

# %%
def risk_parity_objective(weights, cov_matrix):
    #Want risk contribution to be equal to each other
    risk_contribution = calc_risk_contribution(weights, cov_matrix)

    target = np.mean(risk_contribution)

    return np.sum((risk_contribution-target)**2)

# %%
def get_risk_parity_weights(cov_matrix):
    num_assets = len(cov_matrix)

    weights = np.ones(num_assets) / num_assets

    constraints = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1})
    bounds = [(0, 1) for i in range(num_assets)]

    result = minimize(risk_parity_objective, weights, args=(cov_matrix,),
                      method='SLSQP', bounds=bounds, constraints=constraints)

    return result.x

# %%
def calc_sharpe_ratio(returns, risk_free_rate):
    freq = 12  # Monthly data
    excess = returns - (risk_free_rate / freq)
    return np.mean(excess) / np.std(excess) * np.sqrt(freq)

# %%
dataset = pd.read_csv('drive/MyDrive/EE641 Project/clean_full_data.csv')

returns = dataset[[col for col in dataset.columns if 'return_30d' in col]]
returns = returns.clip(lower=-1, upper=1)

# %%
dataset
# Out:
#       Unnamed: 0   SPY_close  SPY_return_30d  SPY_vol_10d  AAPL_close  \
# 0     2017-12-09  235.169754        0.038690     0.004711   39.800705
# 1     2017-12-10  235.169754        0.038690     0.004711   39.800705
# 2     2017-12-11  235.878296        0.033371     0.004637   40.576191
# 3     2017-12-12  236.294617        0.039065     0.003736   40.348232
# 4     2017-12-13  236.268005        0.037332     0.003708   40.482189
# ...          ...         ...             ...          ...         ...
# 2575  2024-12-27  593.225464       -0.000297     0.012133  255.309296
# 2576  2024-12-28  593.225464       -0.000297     0.012133  255.309296
# 2577  2024-12-29  593.225464       -0.000297     0.012133  255.309296
# 2578  2024-12-30  586.455811       -0.005309     0.012546  251.923019
# 2579  2024-12-31  586.455811       -0.005309     0.012546  251.923019
#
#       AAPL_return_30d  AAPL_vol_10d  MSFT_close  MSFT_return_30d  \
# 0            0.079848      0.008663   77.819023         0.073929
# 1            0.079848      0.008663   77.819023         0.073929
# 2            0.062808      0.011191   78.808418         0.022050
# 3            0.033572      0.011179   79.132042         0.025269
# 4            0.022771      0.008712   78.919350         0.031241
# ...               ...           ...         ...              ...
# 2575         0.135350      0.012133  429.668457         0.014562
# 2576         0.135350      0.012133  429.668457         0.014562
# 2577         0.135350      0.012133  429.668457         0.014562
# 2578         0.105074      0.013197  423.979858        -0.002834
# 2579         0.105074      0.013197  423.979858        -0.002834
#
#       MSFT_vol_10d  ...  MDT_vol_10d     BTC_close  BTC_return_30d  \
# 0         0.017360  ...     0.012498  15178.200195        1.124733
# 1         0.017360  ...     0.012498  15455.400391        1.335309
# 2         0.017652  ...     0.010486  16936.800781        1.664024
# 3         0.017313  ...     0.010009  17415.400391        1.926924
# 4         0.016063  ...     0.009926  16408.199219        1.501444
# ...            ...  ...          ...           ...             ...
# 2575      0.014135  ...     0.008445  94164.859375       -0.018733
# 2576      0.014135  ...     0.008445  95163.929688       -0.005107
# 2577      0.014135  ...     0.008445  93530.226562       -0.040337
# 2578      0.014422  ...     0.009326  92643.210938       -0.039460
# 2579      0.014422  ...     0.009326  92643.210938       -0.039460
#
#       BTC_vol_10d    ETH_close  ETH_return_30d  ETH_vol_10d  market_regime  \
# 0        0.105945   473.502014        0.475617     0.037869            2.0
# 1        0.106311   441.721008        0.476079     0.042822            2.0
# 2        0.107192   515.135986        0.637010     0.067349            2.0
# 3        0.106564   651.431030        1.115668     0.103800            2.0
# 4        0.111847   702.767029        1.218919     0.103744            2.0
# ...           ...          ...             ...          ...            ...
# 2575     0.026862  3328.916992       -0.089776     0.036789            2.0
# 2576     0.022154  3397.902344       -0.050815     0.032827            2.0
# 2577     0.021433  3349.513428       -0.067895     0.028143            2.0
# 2578     0.021360  3356.392578       -0.094263     0.027510            2.0
# 2579     0.021360  3356.392578       -0.094263     0.027510            2.0
#
#       regime_name  is_weekend
# 0            Bull        True
# 1            Bull        True
# 2            Bull       False
# 3            Bull       False
# 4            Bull       False
# ...           ...         ...
# 2575         Bull       False
# 2576         Bull        True
# 2577         Bull        True
# 2578         Bull       False
# 2579         Bull       False
#
# [2580 rows x 193 columns]

# %%
returns
# Out:
#       SPY_return_30d  AAPL_return_30d  MSFT_return_30d  AMZN_return_30d  \
# 0           0.038690         0.079848         0.073929         0.194945
# 1           0.038690         0.079848         0.073929         0.194945
# 2           0.033371         0.062808         0.022050         0.061738
# 3           0.039065         0.033572         0.025269         0.048819
# 4           0.037332         0.022771         0.031241         0.053244
# ...              ...              ...              ...              ...
# 2575       -0.000297         0.135350         0.014562         0.045072
# 2576       -0.000297         0.135350         0.014562         0.045072
# 2577       -0.000297         0.135350         0.014562         0.045072
# 2578       -0.005309         0.105074        -0.002834         0.046435
# 2579       -0.005309         0.105074        -0.002834         0.046435
#
#       GOOGL_return_30d  META_return_30d  NVDA_return_30d  TSLA_return_30d  \
# 0             0.058462         0.049053        -0.020783        -0.033847
# 1             0.058462         0.049053        -0.020783        -0.033847
# 2             0.017704         0.006521        -0.034998         0.025057
# 3             0.015138        -0.016178        -0.063125         0.065452
# 4             0.017763        -0.009774        -0.099128         0.022622
# ...                ...              ...              ...              ...
# 2575          0.078829         0.034989        -0.063243         0.307110
# 2576          0.078829         0.034989        -0.063243         0.307110
# 2577          0.078829         0.034989        -0.063243         0.307110
# 2578          0.090438         0.025222        -0.063100         0.341378
# 2579          0.090438         0.025222        -0.063100         0.341378
#
#       BRK-B_return_30d  UNH_return_30d  ...  COP_return_30d  RTX_return_30d  \
# 0             0.041514        0.074186  ...        0.002138        0.030148
# 1             0.041514        0.074186  ...        0.002138        0.030148
# 2             0.043003        0.051374  ...        0.009373        0.041727
# 3             0.059729        0.066150  ...        0.011092        0.036632
# 4             0.055954        0.070819  ...        0.010361        0.044126
# ...                ...             ...  ...             ...             ...
# 2575         -0.024760       -0.155023  ...       -0.133250       -0.051866
# 2576         -0.024760       -0.155023  ...       -0.133250       -0.051866
# 2577         -0.024760       -0.155023  ...       -0.133250       -0.051866
# 2578         -0.033226       -0.140609  ...       -0.140188       -0.025953
# 2579         -0.033226       -0.140609  ...       -0.140188       -0.025953
#
#       CAT_return_30d  BMY_return_30d  SBUX_return_30d  GS_return_30d  \
# 0           0.050533        0.024118         0.073037       0.038957
# 1           0.050533        0.024118         0.073037       0.038957
# 2           0.043248        0.051385         0.082050       0.038087
# 3           0.050773        0.040105         0.080007       0.073061
# 4           0.094035        0.029355         0.090539       0.057255
# ...              ...             ...              ...            ...
# 2575       -0.057380       -0.012498        -0.069934      -0.025555
# 2576       -0.057380       -0.012498        -0.069934      -0.025555
# 2577       -0.057380       -0.012498        -0.069934      -0.025555
# 2578       -0.062861       -0.041709        -0.081525      -0.020759
# 2579       -0.062861       -0.041709        -0.081525      -0.020759
#
#       INTU_return_30d  MDT_return_30d  BTC_return_30d  ETH_return_30d
# 0            0.025772        0.007832        1.000000        0.475617
# 1            0.025772        0.007832        1.000000        0.476079
# 2            0.014466       -0.000369        1.000000        0.637010
# 3            0.029053        0.018254        1.000000        1.000000
# 4            0.036155        0.017387        1.000000        1.000000
# ...               ...             ...             ...             ...
# 2575        -0.095830       -0.074246       -0.018733       -0.089776
# 2576        -0.095830       -0.074246       -0.005107       -0.050815
# 2577        -0.095830       -0.074246       -0.040337       -0.067895
# 2578        -0.100548       -0.066293       -0.039460       -0.094263
# 2579        -0.100548       -0.066293       -0.039460       -0.094263
#
# [2580 rows x 63 columns]

# %%
covariance_matrix = returns.cov()
risk_parity_weights = get_risk_parity_weights(covariance_matrix)
risk_parity_returns = np.dot(returns, risk_parity_weights)

# %%
plt.figure(figsize=(8, 6))
plt.title('Risk Parity Portfolio Cumulative Returns')
plt.ylabel('Cumulative Returns')
plt.xlabel('Months')

plt.plot((1 + risk_parity_returns).cumprod())

plt.show()
